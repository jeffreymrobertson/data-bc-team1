# %%
#Bring in dependancies
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from scipy.stats import linregress

# %%
fashion_df = pd.read_csv("Resources/mock_fashion_data_uk_us.csv")

fashion_df.head()
# Out:
#   Product Name      Price              Brand   Category Description    Rating  \
# 0         T5D3  97.509966       Ralph Lauren   Footwear         Bad  1.421706
# 1         Y0V7  52.341277          Ted Baker       Tops    Not Good  1.037677
# 2         N9Q4  15.430975             Jigsaw   Footwear    Very Bad  3.967106
# 3         V2T6  81.116542  Alexander McQueen  Outerwear    Not Good  2.844659
# 4         S7Y1  31.633686     Tommy Hilfiger    Bottoms   Very Good  1.183242
#
#    Review Count Style Attributes Total Sizes Available Sizes  Color  \
# 0           492       Streetwear    M, L, XL              XL  Green
# 1            57          Vintage    M, L, XL              XL  Black
# 2           197       Streetwear     S, M, L               M   Blue
# 3           473           Formal     S, M, L               L    Red
# 4            55           Sporty    M, L, XL               S  Green
#
#   Purchase History  Age Fashion Magazines Fashion Influencers       Season  \
# ...

# %%
#Checking missing values:
fashion_df.isnull().sum()/len(fashion_df)*100
# Out:
# Product Name                    0.0
# Price                           0.0
# Brand                           0.0
# Category                        0.0
# Description                     0.0
# Rating                          0.0
# Review Count                    0.0
# Style Attributes                0.0
# Total Sizes                     0.0
# Available Sizes                 0.0
# Color                           0.0
# Purchase History                0.0
# Age                             0.0
# Fashion Magazines               0.0
# Fashion Influencers             0.0
# Season                          0.0
# Time Period Highest Purchase    0.0
# Customer Reviews                0.0
# Social Media Comments           0.0
# feedback                        0.0
# dtype: float64

# %%
#Checking the characteristics of the data:
fashion_df.describe(include='all')
# Out:
#        Product Name           Price         Brand  Category Description  \
# count       1000000  1000000.000000       1000000   1000000     1000000
# unique        67600             NaN             8        10           7
# top            Z8H4             NaN  Ralph Lauren  Swimwear         Bad
# freq             33             NaN        125575    100328      143636
# mean            NaN       55.001428           NaN       NaN         NaN
# std             NaN       25.979720           NaN       NaN         NaN
# min             NaN       10.000145           NaN       NaN         NaN
# 25%             NaN       32.496717           NaN       NaN         NaN
# 50%             NaN       55.007413           NaN       NaN         NaN
# 75%             NaN       77.511242           NaN       NaN         NaN
# max             NaN       99.999648           NaN       NaN         NaN
#
#                 Rating    Review Count Style Attributes Total Sizes  \
# ...

# %%
# checking Brand value count 
fashion_df['Brand'].value_counts()
# Out:
# Ralph Lauren         125575
# Jigsaw               125307
# Tommy Hilfiger       125275
# Alexander McQueen    125127
# Burberry             124813
# Calvin Klein         124710
# Mulberry             124662
# Ted Baker            124531
# Name: Brand, dtype: int64

# %%
# checking Category value count 
fashion_df['Category'].value_counts()
# Out:
# Swimwear       100328
# Accessories    100291
# Jewelry        100155
# Outerwear      100076
# Tops           100041
# Dresses         99950
# Lingerie        99949
# Footwear        99793
# Activewear      99751
# Bottoms         99666
# Name: Category, dtype: int64

# %%
# checking Description value count 
fashion_df['Description'].value_counts()
# Out:
# Bad          143636
# Very Bad     143528
# Worst        142984
# Not Good     142766
# Best         142560
# Good         142494
# Very Good    142032
# Name: Description, dtype: int64

# %%
# checking Style Attributes value count 
fashion_df['Style Attributes'].value_counts()
# Out:
# Bohemian      100212
# Vintage       100201
# Minimalist    100052
# Streetwear    100042
# Formal         99988
# Edgy           99959
# Preppy         99952
# Casual         99930
# Sporty         99876
# Glamorous      99788
# Name: Style Attributes, dtype: int64

# %%
# checking Total Sizes value count 
fashion_df['Total Sizes'].value_counts()
# Out:
# S, M, L     333805
# M, L, XL    333401
# S, L, XL    332794
# Name: Total Sizes, dtype: int64

# %%
# checking Color value count 
fashion_df['Color'].value_counts()
# Out:
# Blue     250498
# Black    249945
# Green    249891
# Red      249666
# Name: Color, dtype: int64

# %%
# checking Purchase History value count 
fashion_df['Purchase History'].value_counts()
# Out:
# Very Low         100311
# Above Average    100284
# Low              100164
# Average          100046
# Medium           100016
# Negligible        99990
# High              99977
# Below Average     99881
# Significant       99679
# Very High         99652
# Name: Purchase History, dtype: int64

# %%
# checking Age value count 
fashion_df['Age'].value_counts()
# Out:
# 45    21498
# 64    21492
# 51    21450
# 57    21427
# 37    21425
# 34    21412
# 27    21408
# 31    21400
# 30    21388
# 24    21385
# 62    21382
# 46    21364
# 47    21354
# 38    21348
# 54    21340
# 18    21339
# 28    21338
# 21    21312
# 55    21290
# 49    21283
# 61    21278
# 63    21269
# 22    21261
# 40    21260
# 29    21256
# 39    21254
# 43    21251
# 33    21250
# 48    21245
# 32    21238
# 23    21233
# 42    21232
# 53    21230
# 44    21230
# 60    21223
# 41    21215
# 25    21212
# 58    21208
# 20    21196
# 59    21195
# 26    21188
# 50    21180
# 19    21119
# 52    21056
# 36    21055
# 56    21051
# 35    20980
# Name: Age, dtype: int64

# %%
# checking Fashion Magazines value count 
fashion_df['Fashion Magazines'].value_counts()
# Out:
# Fashionista        100355
# Harper's Bazaar    100263
# Vogue              100234
# Marie Claire       100099
# W                  100028
# Elle                99994
# Grazia              99971
# Glamour             99856
# Cosmopolitan        99746
# InStyle             99454
# Name: Fashion Magazines, dtype: int64

# %%
# checking Fashion Influencers value count 
fashion_df['Fashion Influencers'].value_counts()
# Out:
# Olivia Palermo     100273
# Camila Coelho      100273
# Kendall Jenner     100184
# Leandra Medine     100136
# Gigi Hadid         100122
# Chiara Ferragni    100109
# Song of Style       99864
# Aimee Song          99783
# Julie Sariñana      99774
# Negin Mirsalehi     99482
# Name: Fashion Influencers, dtype: int64

# %%
# checking Season value count 
fashion_df['Season'].value_counts()
# Out:
# Spring           167217
# Fall             167194
# Winter           166878
# Fall/Winter      166748
# Spring/Summer    166101
# Summer           165862
# Name: Season, dtype: int64

# %%
# checking Time Period Highest Purchase value count 
fashion_df['Time Period Highest Purchase'].value_counts()
# Out:
# Weekend      200240
# Holiday      200189
# Evening      200088
# Daytime      199857
# Nighttime    199626
# Name: Time Period Highest Purchase, dtype: int64

# %%
# checking Customer Reviews Purchase value count 
fashion_df['Customer Reviews'].value_counts()
# Out:
# Negative    200359
# Positive    200173
# Mixed       200029
# Neutral     200028
# Unknown     199411
# Name: Customer Reviews, dtype: int64

# %%
# checking Social Media Comments value count 
fashion_df['Social Media Comments'].value_counts()
# Out:
# Positive    166815
# Other       166786
# Negative    166778
# Mixed       166731
# Neutral     166658
# Unknown     166232
# Name: Social Media Comments, dtype: int64

# %%
# checking feedback value count 
fashion_df['feedback'].value_counts()
# Out:
# Unknown     166957
# Positive    166853
# Negative    166727
# Mixed       166649
# Neutral     166504
# Other       166310
# Name: feedback, dtype: int64

# %%
# Checking unique data in Brands and Fashion Influencers
brand_df=fashion_df.groupby(['Brand'])['Fashion Influencers'].unique()
brand_df
# Out:
# Brand
# Alexander McQueen    [Chiara Ferragni, Olivia Palermo, Gigi Hadid, ...
# Burberry             [Olivia Palermo, Negin Mirsalehi, Chiara Ferra...
# Calvin Klein         [Aimee Song, Chiara Ferragni, Julie Sariñana, ...
# Jigsaw               [Gigi Hadid, Kendall Jenner, Chiara Ferragni, ...
# Mulberry             [Kendall Jenner, Olivia Palermo, Chiara Ferrag...
# Ralph Lauren         [Chiara Ferragni, Kendall Jenner, Gigi Hadid, ...
# Ted Baker            [Leandra Medine, Chiara Ferragni, Aimee Song, ...
# Tommy Hilfiger       [Song of Style, Olivia Palermo, Chiara Ferragn...
# Name: Fashion Influencers, dtype: object

# %%
Alexander_McQueen_df = fashion_df[fashion_df['Brand'] == 'Alexander McQueen']
Burberry_df = fashion_df[fashion_df['Brand'] == 'Burberry']
Calvin_Klein_df = fashion_df[fashion_df['Brand'] == 'Calvin Klein']
Jigsaw_df = fashion_df[fashion_df['Brand'] == 'Jigsaw']
Mulberry_df = fashion_df[fashion_df['Brand'] == 'Mulberry']
Ralph_Lauren_df = fashion_df[fashion_df['Brand'] == 'Ralph Lauren']
Ted_Baker_df = fashion_df[fashion_df['Brand'] == 'Alexander McQueen']
Tommy_Hilfiger_df = fashion_df[fashion_df['Brand'] == 'Tommy Hilfiger']

# %%
Alexander_McQueen_df.describe(include='all')
# Out:
#        Product Name          Price              Brand  Category Description  \
# count        125127  125127.000000             125127    125127      125127
# unique        56947            NaN                  1        10           7
# top            C5J4            NaN  Alexander McQueen  Swimwear    Very Bad
# freq             10            NaN             125127     12795       18096
# mean            NaN      55.111098                NaN       NaN         NaN
# std             NaN      25.953919                NaN       NaN         NaN
# min             NaN      10.000257                NaN       NaN         NaN
# 25%             NaN      32.760589                NaN       NaN         NaN
# 50%             NaN      55.107801                NaN       NaN         NaN
# 75%             NaN      77.562122                NaN       NaN         NaN
# max             NaN      99.999366                NaN       NaN         NaN
#
# ...

# %%
Burberry_df.describe(include='all')
# Out:
#        Product Name          Price     Brand     Category Description  \
# count        124813  124813.000000    124813       124813      124813
# unique        56837            NaN         1           10           7
# top            U2I3            NaN  Burberry  Accessories    Very Bad
# freq             11            NaN    124813        12574       17989
# mean            NaN      55.183827       NaN          NaN         NaN
# std             NaN      25.956623       NaN          NaN         NaN
# min             NaN      10.000297       NaN          NaN         NaN
# 25%             NaN      32.688421       NaN          NaN         NaN
# 50%             NaN      55.353235       NaN          NaN         NaN
# 75%             NaN      77.625772       NaN          NaN         NaN
# max             NaN      99.998443       NaN          NaN         NaN
#
#                Rating   Review Count Style Attributes Total Sizes  \
# ...

# %%
Calvin_Klein_df.describe(include='all')
# Out:
#        Product Name          Price         Brand    Category Description  \
# count        124710  124710.000000        124710      124710      124710
# unique        56956            NaN             1          10           7
# top            I6M4            NaN  Calvin Klein  Activewear    Very Bad
# freq              9            NaN        124710       12641       17937
# mean            NaN      55.016305           NaN         NaN         NaN
# std             NaN      25.945502           NaN         NaN         NaN
# min             NaN      10.000145           NaN         NaN         NaN
# 25%             NaN      32.596446           NaN         NaN         NaN
# 50%             NaN      54.922756           NaN         NaN         NaN
# 75%             NaN      77.540329           NaN         NaN         NaN
# max             NaN      99.999372           NaN         NaN         NaN
#
#                Rating   Review Count Style Attributes Total Sizes  \
# ...

# %%
Jigsaw_df.describe(include='all')
# Out:
#        Product Name          Price   Brand Category Description  \
# count        125307  125307.000000  125307   125307      125307
# unique        57000            NaN       1       10           7
# top            Q3J2            NaN  Jigsaw  Dresses         Bad
# freq             10            NaN  125307    12722       18075
# mean            NaN      54.940046     NaN      NaN         NaN
# std             NaN      25.988014     NaN      NaN         NaN
# min             NaN      10.000669     NaN      NaN         NaN
# 25%             NaN      32.503638     NaN      NaN         NaN
# 50%             NaN      54.901110     NaN      NaN         NaN
# 75%             NaN      77.384443     NaN      NaN         NaN
# max             NaN      99.997675     NaN      NaN         NaN
#
#                Rating   Review Count Style Attributes Total Sizes  \
# count   125307.000000  125307.000000           125307      125307
# ...

# %%
Mulberry_df.describe(include='all')
# Out:
#        Product Name          Price     Brand     Category Description  \
# count        124662  124662.000000    124662       124662      124662
# unique        56984            NaN         1           10           7
# top            V5H0            NaN  Mulberry  Accessories         Bad
# freq             10            NaN    124662        12665       17948
# mean            NaN      54.883616       NaN          NaN         NaN
# std             NaN      25.983805       NaN          NaN         NaN
# min             NaN      10.000350       NaN          NaN         NaN
# 25%             NaN      32.339128       NaN          NaN         NaN
# 50%             NaN      54.702621       NaN          NaN         NaN
# 75%             NaN      77.442608       NaN          NaN         NaN
# max             NaN      99.998508       NaN          NaN         NaN
#
#                Rating   Review Count Style Attributes Total Sizes  \
# ...

# %%
Ralph_Lauren_df.describe(include='all')
# Out:
#        Product Name          Price         Brand Category Description  \
# count        125575  125575.000000        125575   125575      125575
# unique        57070            NaN             1       10           7
# top            H0Q1            NaN  Ralph Lauren  Dresses         Bad
# freq              9            NaN        125575    12714       18125
# mean            NaN      55.089152           NaN      NaN         NaN
# std             NaN      25.994132           NaN      NaN         NaN
# min             NaN      10.000319           NaN      NaN         NaN
# 25%             NaN      32.517042           NaN      NaN         NaN
# 50%             NaN      55.341582           NaN      NaN         NaN
# 75%             NaN      77.554448           NaN      NaN         NaN
# max             NaN      99.999648           NaN      NaN         NaN
#
#                Rating  Review Count Style Attributes Total Sizes  \
# ...

# %%
Ted_Baker_df.describe(include='all')
# Out:
#        Product Name          Price              Brand  Category Description  \
# count        125127  125127.000000             125127    125127      125127
# unique        56947            NaN                  1        10           7
# top            C5J4            NaN  Alexander McQueen  Swimwear    Very Bad
# freq             10            NaN             125127     12795       18096
# mean            NaN      55.111098                NaN       NaN         NaN
# std             NaN      25.953919                NaN       NaN         NaN
# min             NaN      10.000257                NaN       NaN         NaN
# 25%             NaN      32.760589                NaN       NaN         NaN
# 50%             NaN      55.107801                NaN       NaN         NaN
# 75%             NaN      77.562122                NaN       NaN         NaN
# max             NaN      99.999366                NaN       NaN         NaN
#
# ...

# %%
Tommy_Hilfiger_df.describe(include='all')
# Out:
#        Product Name          Price           Brand  Category Description  \
# count        125275  125275.000000          125275    125275      125275
# unique        56980            NaN               1        10           7
# top            A6D8            NaN  Tommy Hilfiger  Lingerie         Bad
# freq              9            NaN          125275     12703       18221
# mean            NaN      54.910599             NaN       NaN         NaN
# std             NaN      26.010198             NaN       NaN         NaN
# min             NaN      10.000231             NaN       NaN         NaN
# 25%             NaN      32.371479             NaN       NaN         NaN
# 50%             NaN      54.928554             NaN       NaN         NaN
# 75%             NaN      77.507421             NaN       NaN         NaN
# max             NaN      99.996899             NaN       NaN         NaN
#
#                Rating   Review Count Style Attributes Total Sizes  \
# ...

# %%
num_cols=['Price','Rating','Review Count','Age']

# %%
cat_cols=['Brand','Category','Description','Style Attributes','Color',
           'Fashion Magazines','Fashion Influencers','Season','Time Period Highest Purchase',
           'Customer Reviews','Social Media Comments','feedback']

# %%
# Checking how categorical variables contributes to the entire data
fashion_df[cat_cols].melt().groupby(['variable', 'value'])[['value']].count().head(60)
# Out:
#                                         value
# variable            value
# Brand               Alexander McQueen  125127
#                     Burberry           124813
#                     Calvin Klein       124710
#                     Jigsaw             125307
#                     Mulberry           124662
#                     Ralph Lauren       125575
#                     Ted Baker          124531
#                     Tommy Hilfiger     125275
# Category            Accessories        100291
#                     Activewear          99751
#                     Bottoms             99666
#                     Dresses             99950
#                     Footwear            99793
#                     Jewelry            100155
#                     Lingerie            99949
#                     Outerwear          100076
#                     Swimwear           100328
#                     Tops               100041
# Color               Black              249945
# ...

# %%
# countplot of each categorical column
fig, axis = plt.subplots(nrows=6, ncols=2, figsize=(20, 20))

index = 0
for row in range(6):
    for col in range(2):
        sns.countplot(data=fashion_df, x=cat_cols[index], ax=axis[row, col])
        index += 1
        
plt.show()

# %%
for col in cat_cols:
    plt.figure(figsize=(12, 6))  # Set the figure size
    sns.boxplot(data=fashion_df, x=col, y='Price')  # 'Value' represents the numerical column you want to plot against
    plt.title(f'Box Plot of {col}')
    plt.xticks(rotation=45)  # Rotate x-axis labels if needed
    plt.show()

# %%
# countplot of each categorical column
fig, axis = plt.subplots(nrows=6, ncols=2, figsize=(20, 20))

index = 0
for row in range(6):
    for col in range(2):
        sns.countplot(data=Alexander_McQueen_df, x=cat_cols[index], ax=axis[row, col])
        index += 1
        
plt.show()

# %%
# countplot of each categorical column
fig, axis = plt.subplots(nrows=6, ncols=2, figsize=(20, 20))

index = 0
for row in range(6):
    for col in range(2):
        sns.countplot(data=Burberry_df, x=cat_cols[index], ax=axis[row, col])
        index += 1
        
plt.show()

# %%
# countplot of each categorical column
fig, axis = plt.subplots(nrows=6, ncols=2, figsize=(20, 20))

index = 0
for row in range(6):
    for col in range(2):
        sns.countplot(data=Calvin_Klein_df, x=cat_cols[index], ax=axis[row, col])
        index += 1
        
plt.show()

# %%
# countplot of each categorical column
fig, axis = plt.subplots(nrows=6, ncols=2, figsize=(20, 20))

index = 0
for row in range(6):
    for col in range(2):
        sns.countplot(data=Jigsaw_df, x=cat_cols[index], ax=axis[row, col])
        index += 1
        
plt.show()

# %%
# countplot of each categorical column
fig, axis = plt.subplots(nrows=6, ncols=2, figsize=(20, 20))

index = 0
for row in range(6):
    for col in range(2):
        sns.countplot(data=Mulberry_df, x=cat_cols[index], ax=axis[row, col])
        index += 1
        
plt.show()

# %%
# countplot of each categorical column
fig, axis = plt.subplots(nrows=6, ncols=2, figsize=(20, 20))

index = 0
for row in range(6):
    for col in range(2):
        sns.countplot(data=Ralph_Lauren_df, x=cat_cols[index], ax=axis[row, col])
        index += 1
        
plt.show()

# %%
# countplot of each categorical column
fig, axis = plt.subplots(nrows=6, ncols=2, figsize=(20, 20))

index = 0
for row in range(6):
    for col in range(2):
        sns.countplot(data=Ted_Baker_df, x=cat_cols[index], ax=axis[row, col])
        index += 1
        
plt.show()

# %%
# countplot of each categorical column
fig, axis = plt.subplots(nrows=6, ncols=2, figsize=(20, 20))

index = 0
for row in range(6):
    for col in range(2):
        sns.countplot(data=Tommy_Hilfiger_df, x=cat_cols[index], ax=axis[row, col])
        index += 1
        
plt.show()

# %% [markdown]
# ## Pie chart representing Brand vs Value Count

# %%
size_data = fashion_df["Brand"].value_counts()
plt.title("Brand vs Value Count")
size_data.plot.pie(autopct= "%1.1f%%")
plt.show()

# %% [markdown]
# ## Pie chart representing Brand vs Price

# %%
fashion_df.groupby(['Brand']).sum().plot(kind='pie', y='Price', autopct='%1.0f%%',
                               figsize=(11, 11),title='Brand Vs Price')
# Out:
# <Axes: title={'center': 'Brand Vs Price'}, ylabel='Price'>

# %% [markdown]
# ## Bar chart representing Brand vs Customer Reviews vs Social Media Comments vs      Feedback

# %%
cat_cols_selected=['Brand','Customer Reviews','Social Media Comments','feedback']

# %%
# countplot of each categorical column
fig, axis = plt.subplots(nrows=2, ncols=2, figsize=(25, 10))

index = 0
for row in range(2):
    for col in range(2):
        sns.countplot(data=fashion_df, x=cat_cols_selected[index], ax=axis[row, col])
        index += 1
        
plt.show()

# %% [markdown]
# ## Pie chart representing Age Vs Social Media Comments

# %%
fashion_df.groupby(['Social Media Comments']).sum().plot(kind='pie', y='Age', autopct='%1.0f%%',
                               figsize=(8, 8),title='Age Vs Social Media Comments')
# Out:
# <Axes: title={'center': 'Age Vs Social Media Comments'}, ylabel='Age'>
